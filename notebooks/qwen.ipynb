# %%
# !pip install transformers torch huggingface_hub
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "/Users/genesisdeleon/Downloads/MLAI-Stack/public/models/Qwen1.5-0.5B-Chat"
save_dir = "../public/models"

# Download and save tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name) #, local_files_only=True)
tokenizer.save_pretrained(save_dir)

# Download and save model weights
model = AutoModelForCausalLM.from_pretrained(model_name) #, local_files_only=True)
model.save_pretrained(save_dir)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 12
#       9 tokenizer.save_pretrained(save_dir)
#      11 # Download and save model weights
# ---> 12 model = AutoModelForCausalLM.from_pretrained(model_name) #, local_files_only=True)
#      13 model.save_pretrained(save_dir)
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:604, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     602     if model_class.config_class == config.sub_configs.get("text_config", None):
#     603         config = config.get_text_config()
# --> 604     return model_class.from_pretrained(
#     605         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     606     )
#     607 raise ValueError(
#     608     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     609     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     610 )
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:288, in restore_default_dtype.<locals>._wrapper(*args, **kwargs)
#     286 old_dtype = torch.get_default_dtype()
#     287 try:
# --> 288     return func(*args, **kwargs)
#     289 finally:
#     290     torch.set_default_dtype(old_dtype)
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:5027, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    5017 if (
#    5018     gguf_file
#    5019     and device_map is not None
#    5020     and ((isinstance(device_map, dict) and "disk" in device_map.values()) or "disk" in device_map)
#    5021 ):
#    5022     raise RuntimeError(
#    5023         "One or more modules is configured to be mapped to disk. Disk offload is not supported for models "
#    5024         "loaded from GGUF files."
#    5025     )
# -> 5027 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    5028     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    5029     subfolder=subfolder,
#    5030     variant=variant,
#    5031     gguf_file=gguf_file,
#    5032     from_tf=from_tf,
#    5033     from_flax=from_flax,
#    5034     use_safetensors=use_safetensors,
#    5035     cache_dir=cache_dir,
#    5036     force_download=force_download,
#    5037     proxies=proxies,
#    5038     local_files_only=local_files_only,
#    5039     token=token,
#    5040     user_agent=user_agent,
#    5041     revision=revision,
#    5042     commit_hash=commit_hash,
#    5043     is_remote_code=cls._auto_class is not None,
#    5044     transformers_explicit_filename=transformers_explicit_filename,
#    5045 )
#    5047 is_sharded = sharded_metadata is not None
#    5048 is_quantized = hf_quantizer is not None
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:1102, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash, is_remote_code, transformers_explicit_filename)
#    1097         raise OSError(
#    1098             f"Error no file named {_add_variant(SAFE_WEIGHTS_NAME, variant)} found in directory"
#    1099             f" {pretrained_model_name_or_path}."
#    1100         )
#    1101     else:
# -> 1102         raise OSError(
#    1103             f"Error no file named {_add_variant(WEIGHTS_NAME, variant)}, {_add_variant(SAFE_WEIGHTS_NAME, variant)},"
#    1104             f" {TF2_WEIGHTS_NAME}, {TF_WEIGHTS_NAME + '.index'} or {FLAX_WEIGHTS_NAME} found in directory"
#    1105             f" {pretrained_model_name_or_path}."
#    1106         )
#    1107 elif os.path.isfile(os.path.join(subfolder, pretrained_model_name_or_path)):
#    1108     archive_file = pretrained_model_name_or_path
#
# OSError: Error no file named pytorch_model.bin, model.safetensors, tf_model.h5, model.ckpt.index or flax_model.msgpack found in directory /Users/genesisdeleon/Downloads/MLAI-Stack/public/models/Qwen1.5-0.5B-Chat.
